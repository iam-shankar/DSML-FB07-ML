# %% [markdown]
# <a href="https://colab.research.google.com/github/iam-shankar/DSML-FB07-ML/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seaborn
#
# Seaborn is a powerful Python visualization library built on top of Matplotlib, providing an intuitive interface for statistical graphics. Below are some of the most commonly used Seaborn plots with explanations and examples:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # 1. Count Plot
#
# A count plot is used to show the count of observations in each categorical bin using bars.
#
# Use case: When you want to visualize the frequency distribution of a categorical variable.

# %%
# Sample data
tips = sns.load_dataset('tips')

# Count plot
sns.countplot(x='day', data=tips)
plt.show()
#🔹 Interpretation: The bars represent the number of occurrences for each category in the dataset.

# %% [markdown]
# The count plot of day shows that Saturday and Sunday have the highest number of customers, while Thursday has the lowest.
# This suggests that people tend to eat out more on weekends.

# %% [markdown]
# # 2. Box Plot (Box-and-Whisker Plot)
#
# A box plot shows the distribution of numerical data based on five summary statistics: minimum, first quartile (Q1), median (Q2), third quartile (Q3), and maximum.
#
# Use case: Useful for detecting outliers and comparing distributions.
#
#
# Interpretation:
#
# The box represents the interquartile range (IQR: Q1 to Q3).
# The horizontal line inside the box is the median.
# The whiskers extend to show the range, and points outside are outliers.

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
plt.show()

# %% [markdown]
# The box plot of total_bill across day shows that bills on Saturdays have a wider spread, indicating high variability in spending.
# The median bill on Sundays is higher than on Thursdays, suggesting that people tend to spend more on weekends.
# There are several outliers (dots above the whiskers), meaning some customers spent significantly more than average.

# %% [markdown]
# # 3. Violin Plot
# A violin plot combines a box plot and a density plot to show both the distribution shape and summary statistics.
#
# Use case: Useful when comparing multiple distributions.
#
# Interpretation:
#
# The width of the violin represents the density of the data at different values.
# It provides better visualization for multimodal distributions compared to a box plot.

# %%
sns.violinplot(x='day', y='total_bill', data=tips)
plt.show()

# %% [markdown]
# The violin plot of total_bill across day shows that Friday has a bimodal distribution, meaning there are two common spending ranges.
# The distribution is wider for weekends, showing more variability in bill amounts.
# The top part of the violins is wider on Sundays, indicating more high-spending customers compared to weekdays.

# %% [markdown]
# # 4. Heatmap
# A heatmap is a color-coded matrix used to visualize relationships between variables, often for correlation matrices.
#
# Use case: When analyzing relationships between numerical variables.
#
# Interpretation:
#
# Darker colors indicate stronger correlations.
# The numbers in each cell represent correlation coefficients.

# %%
# Compute correlation only for numerical columns
corr = tips.select_dtypes(include=['number']).corr()

# Plot heatmap
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# The heatmap of correlations shows that total_bill and tip are highly correlated (0.68), meaning higher bills lead to higher tips.
# The correlation between size (number of people) and total_bill is moderate (0.60), meaning larger groups tend to spend more.
# tip and size have a lower correlation (0.15), suggesting that larger groups do not necessarily tip more per person.

# %% [markdown]
# # 5. Pair Plot
# A pair plot creates scatter plots for pairwise relationships in a dataset.
#
# Use case: Useful for exploring relationships between numerical variables.
#
# hue can be categorical
#
# Interpretation:
#
# Diagonal elements show histograms (univariate distribution).
# Off-diagonal elements show scatter plots between features.

# %%
sns.pairplot(tips, hue='sex')
plt.show()

# %% [markdown]
# The scatter plot between total_bill and tip shows a positive correlation, meaning as total_bill increases, tip also increases.
# The histogram on the diagonal shows that most tips are below $5, and most bills are below $30.
# The scatter plot of size vs total_bill suggests that larger groups tend to have higher total bills, but the relationship is not perfectly linear.

# %% [markdown]
# # 6. Swarm Plot
# A swarm plot is similar to a strip plot but avoids overlapping points, making it easier to interpret.
#
# Use case: When visualizing distributions while maintaining individual points.
#
# Interpretation: Each dot represents an observation, giving a more detailed view of the distribution.

# %%
sns.swarmplot(x='day', y='total_bill', data=tips)
plt.show()

# %% [markdown]
# The swarm plot of total_bill across day shows that Thursday has the least variability in bill amounts, while Saturday has the widest spread.
# A few high-value bills are present on Saturdays and Sundays, indicating some customers spend significantly more on weekends.
# The points are densely packed in the $10-$20 range, meaning most bills fall within this range across all days.

# %% [markdown]
# # 7. Density Plot (KDE Plot)
#
# A Kernel Density Estimate (KDE) plot is a smoothed version of a histogram.
#
# Use case: Used for estimating the probability density function of a continuous variable.
#
# Interpretation:
#
# Peaks represent where values are most concentrated.
# It gives a smooth estimate of the data distribution.

# %%
sns.kdeplot(tips['total_bill'], shade=True)
plt.show()
# Out:
# <ipython-input-10-64224cfbbbe2>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(tips['total_bill'], shade=True)

# %% [markdown]
# The density plot of total_bill shows a right-skewed distribution, meaning most bills are on the lower end (around $10-$20), but a few reach $50+.
#
# There is a small bump at around $40, suggesting that some customers frequently spend around this amount.

# %% [markdown]
# Count Plot	Count of categorical values
#
#
# Box Plot	Summary statistics & outliers
#
#
# Violin Plot	Distribution shape + Box plot features
#
#
# Heatmap	Correlation matrix visualization
#
#
# Pair Plot	Pairwise relationships in data
#
#
# Swarm Plot	Non-overlapping scatter plot for distributions
#
#
# Density Plot	Smoothed histogram for distributions

# %% [markdown]
# Plot Type	Example Interpretation (Tips Dataset).
#
# Count Plot	Most customers visit on weekends.
#
# Box Plot	Bills are higher & more variable on weekends, with some extreme outliers.
#
# Violin Plot	Weekends have a wider distribution of bills, Friday has two spending peaks.
#
# Heatmap	Total bill & tip are strongly correlated, larger groups spend more but don't necessarily tip more.
#
# Pair Plot	Higher total bill → higher tip, larger groups tend to spend more.
#
# Swarm Plot	Saturday has the widest bill range, Thursday has the most consistent spending.
#
# Density Plot	Most bills are between
# $10-$20, a few high spenders create a right-skewed distribution.

# %%
tips=sns.load_dataset('tips')
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %% [markdown]
# #Palette
#
# Use for Bar plots, box plots, categorical scatter plots
#
# "deep"	Default, strong contrast
#
# "muted"	Softer tones
#
# "bright"	High saturation colors
#
# "pastel"	Light pastel colors
#
# "dark"	Darker shades
#
# "colorblind"	Colors optimized for colorblind viewers
#
# "Set1", "Set2", "Set3"	Categorical colors from Matplotlib
#
# "coolwarm", "hsv", "rainbow"	Gradient-based palettes

# %% [markdown]
# #Cmap
#
# Used for Heatmaps, KDE plots, scatter plots with continuous color
#
# "viridis"	Yellow → Green → Blue (Good for colorblind users)
#
# "plasma"	Yellow → Orange → Purple
#
# "cividis"	Yellow → Blue (High contrast)
#
# "coolwarm"	Blue → Red (Diverging colors)
#
# "magma"	Yellow → Purple (Dark theme)
#
# "Blues", "Greens", "Reds"	Single-color gradients
#
# "jet"	Deprecated, but still used in legacy plots

# %% [markdown]
# #1.Distribution Plots
#
# - displot
# - histplot
# - jointplot
# - pairplot
# - kdeplot

# %%
sns.displot(tips['total_bill'],kde='True')

# %% [markdown]
# #Jointplot

# %%
sns.jointplot(x='total_bill',y='tip',data=tips)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex',cmap='crest')

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde')

# %%
sns.pairplot(tips, hue='sex', cmap='coolwarm')
plt.show()

# %% [markdown]
# #kdeplot

# %%
sns.kdeplot(tips['total_bill'])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# #2.Categorical Plots
#
# - barplot
# - countplot
# - boxplot
# - violenplot
# - swarmplot
# - stripplot

# %% [markdown]
# #barplot

# %%
sns.barplot(x='sex',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# #Count plot

# %%
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# #Boxplot

# %%
sns.boxplot(x='day', y='total_bill', data=tips,hue='smoker')
plt.show()

# %% [markdown]
# #Violin plot

# %%
sns.violinplot(x='day', y='total_bill', data=tips,hue='sex',split=True)
plt.show()

# %% [markdown]
# #Strip plot

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# #swarm plot with violin plot

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# #Matrix
#
# - heatmap
# - clustermap

# %%
numeric_tips = tips.select_dtypes(include=["number"])

# %%
numeric_tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(numeric_tips.corr(),annot=True)
# Out:
# <Axes: >

# %%
flights=sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
fp=flights.pivot_table(index='month',columns='year',values='passengers')
# Out:
# <ipython-input-45-432451d0e878>:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   fp=flights.pivot_table(index='month',columns='year',values='passengers')

# %%
sns.heatmap(fp,linecolor='white',linewidths=1)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# #cluster map

# %%
sns.clustermap(fp,cmap='coolwarm')

# %%
sns.clustermap(fp,cmap='coolwarm',standard_scale=1)

# %% [markdown]
# #Grids
#
# - PairGrid
# - FacetGrid

# %%
iris=sns.load_dataset('iris')
iris.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa

# %%
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g = sns.PairGrid(tips, vars=["total_bill", "tip", "size"])

g.map_diag(sns.histplot, kde=True, color="blue")
g.map_upper(sns.regplot, scatter_kws={"alpha": 0.5}, line_kws={"color": "red"})
g.map_lower(sns.scatterplot, hue=tips["sex"], alpha=0.7)

plt.show()

# %%
fg=sns.FacetGrid(data=tips,col='time',row='smoker')
fg.map(sns.histplot,'total_bill')

# %%
fg=sns.FacetGrid(data=tips,col='time',row='smoker')
fg.map(sns.scatterplot,'total_bill','tip')

# %% [markdown]
# #Regression Plot

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'],scatter_kws={'s':20})

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex')

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,col='sex',row='time')

# %% [markdown]
# #set style

# %%
sns.set_style('ticks') #white, whitegrid, darkgrid
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# #context

# %%
sns.set_context('notebook',font_scale=1) #paper,notebook,poster
sns.countplot(x='sex',data=tips)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# #colormap reference
#
# https://matplotlib.org/stable/gallery/color/colormap_reference.html

# %% [markdown]
# aliceblue, antiquewhite, aqua, aquamarine, azure,
#             beige, bisque, black, blanchedalmond, blue,
#             blueviolet, brown, burlywood, cadetblue,
#             chartreuse, chocolate, coral, cornflowerblue,
#             cornsilk, crimson, cyan, darkblue, darkcyan,
#             darkgoldenrod, darkgray, darkgrey, darkgreen,
#             darkkhaki, darkmagenta, darkolivegreen, darkorange,
#             darkorchid, darkred, darksalmon, darkseagreen,
#             darkslateblue, darkslategray, darkslategrey,
#             darkturquoise, darkviolet, deeppink, deepskyblue,
#             dimgray, dimgrey, dodgerblue, firebrick,
#             floralwhite, forestgreen, fuchsia, gainsboro,
#             ghostwhite, gold, goldenrod, gray, grey, green,
#             greenyellow, honeydew, hotpink, indianred, indigo,
#             ivory, khaki, lavender, lavenderblush, lawngreen,
#             lemonchiffon, lightblue, lightcoral, lightcyan,
#             lightgoldenrodyellow, lightgray, lightgrey,
#             lightgreen, lightpink, lightsalmon, lightseagreen,
#             lightskyblue, lightslategray, lightslategrey,
#             lightsteelblue, lightyellow, lime, limegreen,
#             linen, magenta, maroon, mediumaquamarine,
#             mediumblue, mediumorchid, mediumpurple,
#             mediumseagreen, mediumslateblue, mediumspringgreen,
#             mediumturquoise, mediumvioletred, midnightblue,
#             mintcream, mistyrose, moccasin, navajowhite, navy,
#             oldlace, olive, olivedrab, orange, orangered,
#             orchid, palegoldenrod, palegreen, paleturquoise,
#             palevioletred, papayawhip, peachpuff, peru, pink,
#             plum, powderblue, purple, red, rosybrown,
#             royalblue, rebeccapurple, saddlebrown, salmon,
#             sandybrown, seagreen, seashell, sienna, silver,
#             skyblue, slateblue, slategray, slategrey, snow,
#             springgreen, steelblue, tan, teal, thistle, tomato,
#             turquoise, violet, wheat, white, whitesmoke,
#             yellow, yellowgreen

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',palette='twilight')

# %% [markdown]
# # Analysing Weather Data

# %%
csvfile="https://raw.githubusercontent.com/ArchanaInsights/Datasets/refs/heads/main/weather_data.csv"
weatherdf=pd.read_csv(csvfile)
weatherdf.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0         14.0        73         9.5               82.0  partly cloudy
# 1         39.0        96         8.5               71.0  partly cloudy
# 2         30.0        64         7.0               16.0          clear
# 3         38.0        83         1.5               82.0          clear
# 4         27.0        74        17.0               66.0       overcast
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 0               1010.82         2  Winter              3.5    inland
# 1               1011.43         7  Spring             10.0    inland
# 2               1018.72         5  Spring              5.5  mountain
# 3               1026.25         7  Spring              1.0   coastal
# 4                990.67         1  Winter              2.5  mountain
#
#   Weather Type
# 0        Rainy
# 1       Cloudy
# 2        Sunny
# 3        Sunny
# 4        Rainy

# %%
weatherdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13200 entries, 0 to 13199
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Temperature           13200 non-null  float64
#  1   Humidity              13200 non-null  int64
#  2   Wind Speed            13200 non-null  float64
#  3   Precipitation (%)     13200 non-null  float64
#  4   Cloud Cover           13200 non-null  object
#  5   Atmospheric Pressure  13200 non-null  float64
#  6   UV Index              13200 non-null  int64
#  7   Season                13200 non-null  object
#  8   Visibility (km)       13200 non-null  float64
#  9   Location              13200 non-null  object
#  10  Weather Type          13200 non-null  object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.1+ MB

# %%
weatherdf.describe()
# Out:
#         Temperature      Humidity    Wind Speed  Precipitation (%)  \
# count  13200.000000  13200.000000  13200.000000       13200.000000
# mean      19.127576     68.710833      9.832197          53.644394
# std       17.386327     20.194248      6.908704          31.946541
# min      -25.000000     20.000000      0.000000           0.000000
# 25%        4.000000     57.000000      5.000000          19.000000
# 50%       21.000000     70.000000      9.000000          58.000000
# 75%       31.000000     84.000000     13.500000          82.000000
# max      109.000000    109.000000     48.500000         109.000000
#
#        Atmospheric Pressure      UV Index  Visibility (km)
# count          13200.000000  13200.000000     13200.000000
# mean            1005.827896      4.005758         5.462917
# std               37.199589      3.856600         3.371499
# min              800.120000      0.000000         0.000000
# 25%              994.800000      1.000000         3.000000
# ...

# %%
categorical_cols=weatherdf.select_dtypes('O').columns
categorical_cols
# Out:
# Index(['Cloud Cover', 'Season', 'Location', 'Weather Type'], dtype='object')

# %%
for col in categorical_cols:
  print(f"{col}: \t {weatherdf[col].unique()}")
# Out:
# Cloud Cover: 	 ['partly cloudy' 'clear' 'overcast' 'cloudy']
# Season: 	 ['Winter' 'Spring' 'Summer' 'Autumn']
# Location: 	 ['inland' 'mountain' 'coastal']
# Weather Type: 	 ['Rainy' 'Cloudy' 'Sunny' 'Snowy']

# %%
for col in categorical_cols:
  print(f"{col}: \t {weatherdf[col].nunique()}")
# Out:
# Cloud Cover: 	 4
# Season: 	 4
# Location: 	 3
# Weather Type: 	 4

# %% [markdown]
# # Count plot

# %%
sns.countplot(data=weatherdf,x='Season')
plt.show()

# %%
ax=sns.countplot(data=weatherdf,x='Season')
ax.bar_label(ax.containers[0])
plt.show()

# %%
weatherdf['Season'].value_counts()
# Out:
# Season
# Winter    5610
# Spring    2598
# Autumn    2500
# Summer    2492
# Name: count, dtype: int64

# %% [markdown]
# # subplots

# %%
fig,axes=plt.subplots(nrows=1,ncols=4, figsize=(28,7))

# %% [markdown]
# # zip function example

# %%
ratings=['Excellent',"good","average","poor"]
ratings_count=[100,80,60,50]
list(zip(ratings,ratings_count))
# Out:
# [('Excellent', 100), ('good', 80), ('average', 60), ('poor', 50)]

# %%
fig,axes=plt.subplots(nrows=1,ncols=4, figsize=(28,7))

for col, axis in zip(categorical_cols,axes):
  sns.countplot(data=weatherdf,x=col,ax=axis)
  axis.set_title(f'Distribution of {col}')
  axis.bar_label(axis.containers[0])

plt.tight_layout()
plt.show()

# %%
fig,axes=plt.subplots(nrows=1,ncols=2, figsize=(28,7))

for col, axis in zip(categorical_cols,axes):
  sns.countplot(data=weatherdf,x=col,ax=axis)
  axis.set_title(f'Distribution of {col}')
  axis.bar_label(ax.containers[0])

plt.tight_layout()
plt.show()

# %%
ax=sns.countplot(data=weatherdf,x='Location',hue='Season')
ax.bar_label(ax.containers[0])
plt.show()

# %% [markdown]
# # Bar Plot

# %%
sns.barplot(data=weatherdf,x='Season',y='Temperature')
# Out:
# <Axes: xlabel='Season', ylabel='Temperature'>

# %%
sns.barplot(data=weatherdf,x='Weather Type',y='Visibility (km)',hue="Weather Type",estimator="median")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(data=weatherdf,x='Season',y='Temperature',hue="Weather Type",palette='Set1')
plt.show()

# %% [markdown]
# #Line plot

# %%
sns.lineplot(data=weatherdf,x='Humidity',y="Temperature",errorbar=None,hue="Location")
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(data=weatherdf,x='Wind Speed',y="Temperature",marker='o',errorbar=None,hue="Location",estimator='min')
plt.show()

# %% [markdown]
# # scatter plot

# %%
plt.figure(figsize=(15,6))

sns.scatterplot(data=weatherdf,x="Humidity",y="Precipitation (%)",hue="Cloud Cover")
# Out:
# <Axes: xlabel='Humidity', ylabel='Precipitation (%)'>

# %%
weatherdf.columns
# Out:
# Index(['Temperature', 'Humidity', 'Wind Speed', 'Precipitation (%)',
#        'Cloud Cover', 'Atmospheric Pressure', 'UV Index', 'Season',
#        'Visibility (km)', 'Location', 'Weather Type'],
#       dtype='object')

# %%
sns.scatterplot(data=weatherdf,x="Humidity",y="Precipitation (%)")

# %% [markdown]
# # Box plot

# %%
sns.boxplot(x=weatherdf['UV Index'])
# Out:
# <Axes: xlabel='UV Index'>

# %%
sns.boxplot(data=weatherdf,x='Season',y='UV Index',hue='Season')
plt.show()

# %% [markdown]
# #Histogram

# %%
sns.histplot(weatherdf['Atmospheric Pressure'])
# Out:
# <Axes: xlabel='Atmospheric Pressure', ylabel='Count'>

# %%
plt.figure(figsize=(10,6))
sns.histplot(weatherdf['Atmospheric Pressure'],bins=100,kde=True,color='green')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.histplot(data=weatherdf,x='Atmospheric Pressure',bins=100,hue='Weather Type',multiple='stack')
plt.show()

# %% [markdown]
# # Density Plot - KDE

# %%
sns.kdeplot(weatherdf['Atmospheric Pressure'])
# Out:
# <Axes: xlabel='Atmospheric Pressure', ylabel='Density'>

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(data=weatherdf,x='Atmospheric Pressure',hue='Cloud Cover')
plt.show()

# %%
numerical_cols=weatherdf.select_dtypes(exclude='O').columns
numerical_cols
# Out:
# Index(['Temperature', 'Humidity', 'Wind Speed', 'Precipitation (%)',
#        'Atmospheric Pressure', 'UV Index', 'Visibility (km)'],
#       dtype='object')

# %%
fig,axes=plt.subplots(nrows=2,ncols=4, figsize=(20,7))
axes=axes.flatten()
for col, axis in zip(numerical_cols,axes):
  sns.kdeplot(data=weatherdf,x=col,ax=axis,fill=True)
  axis.set_title(f'Distribution of {col}')


plt.tight_layout()
plt.show()

# %% [markdown]
# # Plots Category
#
# - Univariate - plots display the distribution or summary of single variable. Eg. Count plot, Histogram
#
# - Bivariate - plots show the relationship between two variables. Eg: Scatter, Line
#
# - Multivariate - plots reveal relationship among multiple variables. Eg: Heatmap, Pair plot.
